# %% [markdown]
# # 02 — Feature engineering
# Build per-patient aggregates used by `training/train.py`.

# %%
import sys
from pathlib import Path

root = Path("..").resolve()
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

import pandas as pd
from preprocessing.ehr_loader import load_data
from feature_engineering.patient_features import create_features

df = load_data(root / "data" / "raw" / "sample_ehr.csv")
features = create_features(df)
features
