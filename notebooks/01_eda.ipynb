# %% [markdown]
# # 01 — EDA (sample EHR)
# Load `data/raw/sample_ehr.csv` and inspect distributions.

# %%
import pandas as pd
from pathlib import Path

root = Path("..").resolve()
df = pd.read_csv(root / "data" / "raw" / "sample_ehr.csv")
df.head()

# %%
df.describe()
